# %%
from wmyblog import *
os.environ['http_proxy'] = "http://127.0.0.1:7890" #代理的端口
os.environ['https_proxy'] = "http://127.0.0.1:7890"

# %%
updateArticle()
genHTMLAll() # 利用文章和评论的pkl文件生成独立的html文件 [不需要联网]
genINDEX() # 生成文章目录index.html [不需要联网]
# Out:
# Fetching article: 【美國】【國際】2022年國際局勢的回顧與展望
# Fetching article: 【工業】【能源】再談氫經濟
# Fetching article: 【宣佈】讀者須知
# Fetching article: 【宣佈】如何支持這個部落格
# Fetching article: 【科技】量子通信和計算是中國學術管理的頭號誤區
# Fetching article: 【國際】歐盟内部的無色革命
# Fetching article: 【外交】【戰略】美國制華歷程分析及對中國外交政策調整的建議
# Fetching article: 【學術管理】中國的學術管理問題來自基本的邏輯謬誤
# Fetching article: 【金融】我對引入美國投行的一些看法
# Fetching article: 【歷史】冷戰、學運和五四運動
# Fetching article: 【宣佈】Whoops，不小心刪了一些值得保留的討論
# Fetching article: 【國際】【宣傳】如何破解當前歐美的宣傳攻勢
# Fetching article: 【國際】再談Biden任期内的中美博弈等議題
# Fetching article: 【宣佈】幾則博客事務和感言
# Fetching article: 【國際】新年的回顧與展望（三）
# Fetching article: 【美國】【國際】新年的回顧與展望（二）
# Fetching article: 【美國】【國際】新年的回顧與展望（一）
# Fetching article: 【學術管理】從假大空談新時代的學術管理
# Fetching article: 【歷史】歐系文明的起源
# Fetching article: 【歷史】根深蒂固的誤解（三）
# Fetching article: 【美國】【工業】熱帶風暴之後
# Fetching article: 【歷史】【戰略】希特勒的戰略選擇
# Fetching article: 【邏輯】一個重要的統計悖論
# Fetching article: 【空軍】【海軍】根深蒂固的誤解（二）
# Fetching article: 【歷史】【陸軍】根深蒂固的誤解（一）
# Fetching article: 【美國】【政治】談美國的反種族歧視運動
# Fetching article: 【歷史】【軍事】現代諸葛弩
# Fetching article: 【金融】【戰略】後新冠世界（二）
# Fetching article: 【外交】【經貿】後新冠世界（一）
# Fetching article: 【國際】有關瑞典的一些觀察
# Fetching article: 【醫療】我的新冠經驗
# Fetching article: 【科研】流行病的起源（下）
# Fetching article: 【科研】流行病的起源（上）
# Fetching article: 【美國】美國大選中的危險人物
# Fetching article: 【科研】如何解讀nCov的傳染病學參數
# Fetching article: 【科研】【媒體】新冠病毒和媒體亂象
# Fetching article: 【台灣】台灣大選後可行的内政改革
# Fetching article: 【科研】統計與謊言
# Fetching article: 【美國】【工業】幾則新聞
# Fetching article: 【公共健康】【財政】一個嚴重的公共健康問題
# Fetching article: 【外交】【傳媒】現代英美的假新聞體系
# Fetching article: 【美國】【政治】美國崛起時代的治理哲學
# Fetching article: 【美國】【工業】波音衰敗之源
# Fetching article: 【邏輯】常見的狡辯術
# Fetching article: 【金融】【戰略】BRICS高峰會議的重要議程
# Fetching article: 【國際】有關於玻利維亞政變的一些消息
# Fetching article: 【美國】簡評民主黨彈劾Trump
# Fetching article: 【基礎科研】再談Google的量子霸權
# Fetching article: 【海軍】有關航母的一些新消息
# Fetching article: 【藝術】【基礎科研】藝術與科學的衰敗
# Fetching article: 【英國】脫歐鬥爭的細節
# Fetching article: 【軍事】從美國看閲兵
# Fetching article: 【海军】中共海军的两栖攻撃舰
# Fetching article: 【陆军】又见朱日和
# Fetching article: 【空军】【海军】雷达与隐身技术之间的矛盾关系（下）
# Fetching article: 【二炮】中共再次试射WU-14高超音速飞行器
# Fetching article: 【空军】共军小道消息增补：Su-35
# Fetching article: 【空军】【海军】雷达与隐身技术之间的矛盾关系（中）
# Fetching article: 【空军】【海军】雷达与隐身技术之间的矛盾关系（上）
# Fetching article: 【基础科研】中国锦屏地下实验室
# Fetching article: 【二炮】【反导】中共官方证实新东风和红旗飞弹
# Fetching article: 【美国】【歷史】美国的东亜战略史
# Fetching article: 【海军】054A级护卫舰
# Fetching article: 【美国】【歷史】美国小官僚的大错误
# Fetching article: 【海军】中共的新一代反舰飞弹
# Fetching article: 【反导】中共再次成功进行陆基反导试验
# Fetching article: 【陆军】【防空】习近平的军事改革和共军的实兵对抗
# Fetching article: 【空军】【海军】共军小道消息总匯
# Fetching article: 【防空】【当前新闻】对MH17事件之分析之二
# Fetching article: 【空军】【自由时报】一架F22戦机完胜中共空军？
# Fetching article: 【防空】【当前新闻】对MH17事件之分析
# d:\wmyblog\wmyblog.py:97: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_article = df_article_new.append(df_article_old,ignore_index=True)
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23464/3911299423.py in <module>
# ----> 1 updateArticle()
#       2 genHTMLAll() # 利用文章和评论的pkl文件生成独立的html文件 [不需要联网]
#       3 genINDEX() # 生成文章目录index.html [不需要联网]
#
# d:\wmyblog\wmyblog.py in updateArticle(articleFile)
#      97     df_article = df_article_new.append(df_article_old,ignore_index=True)
#      98     df_article = df_article.drop_duplicates()
# ---> 99     os.rename(articleFile,articleFile+'.bak')
#     100     df_article.to_pickle(articleFile)
#     101     return
#
# FileExistsError: [WinError 183] 当文件已存在时，无法创建该文件。: './data/article_full.pkl' -> './data/article_full.pkl.bak'

# %%
import pdfkit
import pandas as pd
import json

# %%
df = pd.read_pickle('./data/article_full.pkl')

# %%
for idx in df.index:
    id = df.loc[idx,'id']
    title = df.loc[idx,'title']
    d = df.loc[idx,'art_date']
    try:
        pdfkit.from_file('./html/'+id+'.html','./pdf/'+d.strftime('%Y-%m-%d %H')+' '+title+'.pdf')
    except:
        pass

# %%
pdfkit.from_file('D:\\wmyblog\\html\\108908611.html','D:\\wmyblog\\pdf\\1.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pdfkit\configuration.py in __init__(self, wkhtmltopdf, meta_tag_prefix, environ)
#      34
# ---> 35             with open(self.wkhtmltopdf) as f:
#      36                 pass
#
# FileNotFoundError: [Errno 2] No such file or directory: b''
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17648/2634795859.py in <module>
# ----> 1 pdfkit.from_file('D:\\wmyblog\\html\\108908611.html','D:\\wmyblog\\pdf\\1.pdf')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pdfkit\api.py in from_file(input, output_path, options, toc, cover, css, configuration, cover_first, verbose)
#      46     """
#      47
# ---> 48     r = PDFKit(input, 'file', options=options, toc=toc, cover=cover, css=css,
#      49                configuration=configuration, cover_first=cover_first, verbose=verbose)
#      50
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pdfkit\pdfkit.py in __init__(self, url_or_file, type_, options, toc, cover, css, configuration, cover_first, verbose)
#      43
#      44         self.source = Source(url_or_file, type_)
# ---> 45         self.configuration = (Configuration() if configuration is None
#      46                               else configuration)
#      47         try:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pdfkit\configuration.py in __init__(self, wkhtmltopdf, meta_tag_prefix, environ)
#      36                 pass
#      37         except (IOError, FileNotFoundError) as e:
# ---> 38             raise IOError('No wkhtmltopdf executable found: "%s"\n'
#      39                           'If this file exists please check that this process can '
#      40                           'read it or you can pass path to it manually in method call, '
#
# OSError: No wkhtmltopdf executable found: "b''"
# If this file exists please check that this process can read it or you can pass path to it manually in method call, check README. Otherwise please install wkhtmltopdf - https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

# %%
from wmyblog import *

# %%
commentFile = './data/comment_full.pkl'
df_comment_old = pd.read_pickle(commentFile)
df_comment_new = pd.DataFrame(columns = ['comment','reply','nickname','date','id'])

url = "https://blog.udn.com/blog/inc_2011/psn_article_ajax.jsp?uid=MengyuanWang&f_FUN_CODE="

# update comment items
response = requests.get(url+"new_rep")
doc = BeautifulSoup(response.content,features="lxml")
docu = doc.findAll(class_="main-title")
dict_reply = {'0':'0'}
for i in docu:
    art_id = i.attrs['href'].replace('https://blog.udn.com/MengyuanWang/','')
    nPage,df = getComment(art_id)
    if nPage > 1:
        nPage,df1 = getComment(art_id,n=1)
        df = pd.concat([df,df1],ignore_index=True)
    df.date = df.date.astype('object')
    df1 = df_comment_old.loc[(df_comment_old.id == art_id) & (df_comment_old.date >= min(df.date))].copy()
    df_merge = pd.merge(df,df1,indicator=True,how='outer')
    for idx in df_merge.loc[df_merge['_merge'] == 'right_only'].index:
        df_merge.loc[idx,'comment'] = '<strike>'+df_merge.loc[idx,'comment']+'</strike>'
    df_merge = df_merge.drop(columns=['_merge'])
    df_comment_new = pd.concat([df_comment_new,df_merge],ignore_index=True)
    dict_reply[art_id] = i.text
df_comment = pd.concat([df_comment_new,df_comment_old],ignore_index=True)
df_comment = df_comment.drop_duplicates(subset=['nickname','date'],keep='first')
df_comment = df_comment.reset_index(drop=True)
# Out:
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)
# d:\github\wmyblog\wmyblog.py:525: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(s,ignore_index=True)

# %%
df_comment.loc[df_comment.comment.str.contains('/strike')]
# Out:
#                                               comment reply    nickname  \
# 20  <strike> \n今天美國居然不允許俄羅斯央行使用美元，這簡直是美國幫助別的國家進行去美...        pedagogicM
# 21  <strike>请问王兄怎么看 2月27日尼泊尔议会批准尼同美国“千年挑战计划”协议（MCC...           雷霆霹雳震霪霾
# 22  <strike>这次战争对整个世界金融体系啥影响   比如西方把俄罗斯的很多银行提出 swi...              弃车成杀
# 23  <strike>王先生，您好。您说的中国和欧盟的关系不至于“跌落悬崖”是一种什么状态？是不是...             游客 越雷
# 24  <strike>　\n最新的新聞德國真的像烏克蘭運送單兵非對稱作戰武器(如標槍反坦克導彈和刺...               　　.
# 25  <strike>　\n我相當擔心西方國家會暗中運送大量單兵作戰的標槍反坦克導彈和刺針飛彈給烏...               　　.
# 55  <strike>中方是否有能在整體國力超越美國後達成和統的可能？台灣內部還是有親中的勢力，只...        jay2005195
# 56  <strike>回复楼上弃车成杀\n王先生应该不太喜欢讨论一个方向已经确定，只是细节需要随着...            文科生基督徒
# 57  <strike>我其实觉得统一很难 由于近几年电子产业需求很大 台湾会有好几年好看的经济数据...              弃车成杀
# 58  <strike>這就是台獨政客的如意算盤啊，各位。流亡政府是有權處置海外資產的，至少在美國的...                K.
# 59  <strike>回覆97樓：\n我覺得你判斷到時美國會凍結(其實就是沒收)台灣的萬億美元海外...           SirChen
# 98  <strike>王博您好，\n斗胆抛砖，德国暂停北溪II，自断双手。俄国因此没达到很好的离间...              興中居士
#
#                    date         id
# 20  2022-02-28 22:31:00  171423818
# 21  2022-02-28 20:50:00  171423818
# 22  2022-02-28 12:30:00  171423818
# 23  2022-02-27 20:22:00  171423818
# 24  2022-02-27 09:05:00  171423818
# 25  2022-02-27 08:53:00  171423818
# 55  2022-02-28 18:56:00  128020354
# 56  2022-01-14 17:28:00  128020354
# 57  2022-01-14 10:48:00  128020354
# 58  2021-09-06 19:45:00  128020354
# 59  2021-09-06 15:44:00  128020354
# 98  2022-02-24 18:41:00  171633910

# %%
# Out:
# 0     2022-03-01 08:56:00
# 1     2022-03-01 02:23:00
# 2     2022-03-01 01:09:00
# 3     2022-03-01 00:57:00
# 4     2022-02-28 22:52:00
# 5     2022-02-28 13:41:00
# 6     2022-02-28 13:39:00
# 7     2022-02-28 01:04:00
# 8     2022-02-28 00:49:00
# 9     2022-02-28 00:46:00
# 10    2022-02-27 23:15:00
# 11    2022-02-27 23:14:00
# 12    2022-02-27 23:01:00
# 13    2022-02-27 16:12:00
# 14    2022-02-27 11:53:00
# 15    2022-02-27 11:52:00
# 16    2022-02-27 09:41:00
# 17    2022-02-27 06:52:00
# 18    2022-02-27 06:18:00
# 19    2022-02-27 00:59:00
# Name: date, dtype: object

# %%
pd.merge(df,df1,indicator=True,how='outer',on=['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15244/1441937738.py in <module>
# ----> 1 pd.merge(df,df1,indicator=True,how='outer',on=['date'])
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     702         # validate the merge keys dtypes. We may need to coerce
#     703         # to avoid incompatible dtypes
# --> 704         self._maybe_coerce_merge_keys()
#     705
#     706         # If argument passed to validate,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1259             # datetimelikes must match exactly
#    1260             elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
# -> 1261                 raise ValueError(msg)
#    1262             elif not needs_i8_conversion(lk.dtype) and needs_i8_conversion(rk.dtype):
#    1263                 raise ValueError(msg)
#
# ValueError: You are trying to merge on datetime64[ns] and object columns. If you wish to proceed you should use pd.concat

# %%
df.date[0]
# Out:
# Timestamp('2022-03-01 08:56:00')

# %%
id_list = df_comment_new.id.drop_duplicates()
id = id_list[0]
df1 = df_comment_new.loc[df_comment_new.id == id].copy()
df2 = df_comment_old.loc[(df_comment_old.id == id) & (df_comment_old.date >= min(df1.date))].copy()

# %%
df_merge
# Out:
#                                               comment  \
# 0   有无可能普京一开始没打算快速推进，有个重要原因是想极限施压，逼某些国家站队，尤其是意图把中国...
# 1   　\n現在美國網路社群媒體網站叫喊著要封鎖俄羅斯RT，之前已經有推特和官方FB被封鎖的消息，...
# 2   乌克兰亚速营的前身来自于网络上的极右翼思潮，这些极右翼人士得到西方的青睐从而得到资金和组织上...
# 3   其实日本，韩国（不过起码韩国左翼执政精英还有事大的嗅觉）也是的，这个名单可以一直列下去，就连...
# 4    \nI personally think it wouldn't be very prod...
# 5   我明白了, 开弓没有回头箭, 事已至此. 俄方能否干脆向乌克兰提出条件, 不允许乌克兰加入北...
# 6   战后乌克兰的治理\n请教王先生，如果无法在乌克兰找到合适的代理人进行治理，俄罗斯是否存在直接...
# 7   　　其實台灣跟烏克蘭真的很像，誠如王兄所言：能為德國帶來歐洲和平的是俄國而不是美國，能讓德國...
# 8   我覺得普亭並沒有太多的選擇或最優解，烏軍如果不投降他只有痛下殺手。因為他知道烏克蘭的仇俄已然...
# 9   目前台灣媒體在報導俄烏戰事上經常都不查證實情，只是直接翻譯歐美同行的文章，所以如非一直閱讀王...
# 10  …….看了Putin對烏克蘭的幾場談話嗎？一個鐵血硬漢說出那些充滿感性的回顧，很讓我吃驚。其...
# 11  回50楼，个人认为我们需要观察俄罗斯的部队是否已经开始对利沃夫区域发起了攻击（乌克兰最西边的...
# 12  目前來看，雙方各讓了一步，有起碼的談判誠意。\n俄方：同意無條件談判（沒再提去軍事化／去納粹...
# 13  我猜测的一个善后方案，参考第一次海湾战争后的伊拉克，先北起列宁格勒，南到摩尔多瓦画一条大致的...
# 14      请问基于历史情怀有一些幻想是何意？基于俄乌历史同源的情怀吗？普京居然天真到这种地步吗？\n
# 15  請教王先生，歐盟在這件事上全力站隊美國，是否很可能對中歐關係造成進一步負面影響？ 歐盟的選擇...
# 16  　\n集中在一篇好了，我相當擔心西方國家會暗中運送大量單兵作戰的標槍反坦克導彈和刺針飛彈給烏...
# 17  從先生對Scholz、Merkel、和Putin的分析，是否可推論出，比起Scholz自身的...
# 18  普丁理性，對手瘋狂。感覺西方世界對於烏克蘭分析出現很大的問題了，憑白創造一個俄羅斯吞掉整個烏...
# 19  今天下午才看到消息：俄国BTG出现在乌克兰西部的利沃夫，机降部队也在陆续抢占关键位置，这基本...
# 20  <strike> \n今天美國居然不允許俄羅斯央行使用美元，這簡直是美國幫助別的國家進行去美...
# 21  <strike>请问王兄怎么看 2月27日尼泊尔议会批准尼同美国“千年挑战计划”协议（MCC...
# 22  <strike>这次战争对整个世界金融体系啥影响   比如西方把俄罗斯的很多银行提出 swi...
# 23  <strike>王先生，您好。您说的中国和欧盟的关系不至于“跌落悬崖”是一种什么状态？是不是...
# 24  <strike>　\n最新的新聞德國真的像烏克蘭運送單兵非對稱作戰武器(如標槍反坦克導彈和刺...
# 25  <strike>　\n我相當擔心西方國家會暗中運送大量單兵作戰的標槍反坦克導彈和刺針飛彈給烏...
#
#                                                 reply    nickname  \
# 0                                                            龙行天下
# 1              \n\n俄方如何因應這一輪金融制裁，是新博文的討論重點之一；請稍安勿躁。\n         　　.
# 2   \n\n沒有什麽英勇無畏，至少沒有真實可靠的證據可以那麽判斷：俄軍的進展在任何客觀合理的標準...   Submarine
# 3   \n\n現實世界中的昂撒集團是如此的下流無恥，做出正確認知不是紅不紅的問題，只要有點腦子、更...        乌鹊南飞
# 4   \n\n我同意沒有必要對軍事進展太過關注，但原因不是難以預測，剛好相反，是因爲俄軍勝利是絕對...         AAB
# 5   \n\n已經撕破臉，沒有妥協餘地了；現在俄方的選擇，只有頑抗到底和實質投降兩條路。如果出現你...       AbzX5
# 6   \n\n非常不理想：如果被逼至此，會有更糟糕的長期惡果。不過這都是在開戰前就應該徹底論證的可...    criteria
# 7   \n\n我早説過，實名發言有風險，所以不方便繼續針對性地評論台灣局勢。但最近我和大家談得很高...         貓靈子
# 8   \n之前我說Putin可能有些幻想，指的就是他似乎還指望王師一到、望風披靡。事實上這不但事先...   desertfox
# 9   \n\n事後的確有依戰犯罪和反人類罪起訴Zelensky和右區頭目的選項，不過機率不大；我想...         貓靈子
# 10  \n\n我對他的印象，和你一樣，所以我並不是不同意他的目標，而只是質疑他的方法選擇是否最優。...   desertfox
# 11  \n\nZelensky真正以爲自己處在好萊塢電影宇宙之中：美國就是好人，俄國就是壞人，只要...    criteria
# 12  \nZelensky是真心相信白左那一套，現在只是繼續表演一個“危機下的英雄總統”，實際上對...        南山臥蟲
# 13  \n\n全面掃清抵抗，然後强加新憲法，一出手就已經是定局；問題只在於占領的方式和長久，以及最...       AbzX5
# 14  \n\n你看了Putin對烏克蘭的幾場談話嗎？一個鐵血硬漢說出那些充滿感性的回顧，很讓我吃驚...        乌鹊南飞
# 15  \n德國新政府的問題在於他們笨、沒有理性和主見，所以被美國玩弄使喚；然而美國人並不是他們唯一...     SirChen
# 16  \n\n上次承諾的5000頂頭盔還沒有送到呢。這場仗頂多十幾天，哪兒來得及等歐盟國家的官僚慢...         　　.
# 17  \n\n是的，你總結得很好。攻下烏克蘭，北溪就毫無意義，等同放棄過去7年的頭號努力成果，可見...    芳草鮮美落英繽紛
# 18  \n\n現在是21世紀了，瓜分國土的事在公關上非常難看，更何況波蘭對俄國有反射式的仇恨，而P...    yoyomama
# 19  \n\n烏克蘭國土東西狹長，大半部隊卻部署在東烏前綫，俄方又從北東南三面對其包圍，所以俄軍作...   Submarine
# 20                                                     pedagogicM
# 21                                                        雷霆霹雳震霪霾
# 22                                                           弃车成杀
# 23                                                          游客 越雷
# 24                                                            　　.
# 25                                                            　　.
#
#                    date         id
# 0   2022-03-01 08:56:00  171423818
# 1   2022-03-01 02:23:00  171423818
# 2   2022-03-01 01:09:00  171423818
# 3   2022-03-01 00:57:00  171423818
# 4   2022-02-28 22:52:00  171423818
# 5   2022-02-28 13:41:00  171423818
# 6   2022-02-28 13:39:00  171423818
# 7   2022-02-28 01:04:00  171423818
# 8   2022-02-28 00:49:00  171423818
# 9   2022-02-28 00:46:00  171423818
# 10  2022-02-27 23:15:00  171423818
# 11  2022-02-27 23:14:00  171423818
# 12  2022-02-27 23:01:00  171423818
# 13  2022-02-27 16:12:00  171423818
# 14  2022-02-27 11:53:00  171423818
# 15  2022-02-27 11:52:00  171423818
# 16  2022-02-27 09:41:00  171423818
# 17  2022-02-27 06:52:00  171423818
# 18  2022-02-27 06:18:00  171423818
# 19  2022-02-27 00:59:00  171423818
# 20  2022-02-28 22:31:00  171423818
# 21  2022-02-28 20:50:00  171423818
# 22  2022-02-28 12:30:00  171423818
# 23  2022-02-27 20:22:00  171423818
# 24  2022-02-27 09:05:00  171423818
# 25  2022-02-27 08:53:00  171423818

# %%
df_comment = df_comment_new.append(df_comment_old, ignore_index=True)
df_comment = df_comment.drop_duplicates(subset=['comment'],keep='first')
df_comment = df_comment.reset_index(drop=True)
