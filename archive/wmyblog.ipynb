# %%
import pandas as pd
import hashlib

tag_file = f"../data/tag.pkl"
df_tag = pd.read_pickle(tag_file)

comment_file = f"../data/comment_full.pkl"
df_comment = pd.read_pickle(comment_file)

# %%
df_comment = df_comment.drop_duplicates(subset=["reply"])

# %%
import numpy as np

df_comment = df_comment.loc[df_comment["reply"] != ""]
df_comment["count1"] = df_comment["comment"].map(lambda x: len(x))
df_comment["stat1"] = df_comment["comment"].map(lambda x: np.log(len(x)))
df_comment["count2"] = df_comment["reply"].map(lambda x: len(x))
df_comment["stat2"] = df_comment["reply"].map(lambda x: np.log(len(x)))
# mean = df_comment["stat"].mean()
# std = df_comment["stat"].std()

# a = 1
# len(df_comment.loc[(df_comment["stat"] > mean - a*std) & (df_comment["stat"] < mean + a*std)]) / len(df_comment)

# %%
df_comment.plot(x="stat1", y="stat2", marker=".", linestyle="none")
# Out:
# <Axes: xlabel='stat1'>

# %%
df_comment["stat"].hist()
# Out:
# <Axes: >

# %%
import pandas as pd

data_file = "../data/transcript_data.pkl"
df = pd.read_pickle(data_file)
df
# Out:
#                                                   url  \
# 1   https://docs.google.com/document/d/1eR6tf5TZMp...
# 2   https://docs.google.com/document/d/1l2zCInnz3d...
# 3   https://docs.google.com/document/d/1HWscAznOKt...
# 4   https://docs.google.com/document/d/1Io1KSxkuYw...
# 5   https://docs.google.com/document/d/1E-DHG84y4-...
# ..                                                ...
# 67  https://docs.google.com/document/d/1ddGAfNQJhP...
# 68  https://docs.google.com/document/d/1380MnCAmHp...
# 69  https://docs.google.com/document/d/13XfD78wJwh...
# 70  https://docs.google.com/document/d/19He10g4o3_...
# 71  https://docs.google.com/document/d/1fPvn_yTorz...
#
#                                              response  status
# 1   b'<!DOCTYPE html><html lang="zh-CN"><head><scr...     200
# 2   b'<!DOCTYPE html><html lang="zh-CN"><head><scr...     200
# 3   b'<!DOCTYPE html><html lang="zh-CN"><head><scr...     200
# 4   b'<!DOCTYPE html><html lang="zh-CN"><head><scr...     200
# ...

# %%
from bs4 import BeautifulSoup

response = df.loc[1, "response"]
doc = BeautifulSoup(response)
doc
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN"><head><script nonce="IqF3eCe5366MgCG7Z27ugw">window['ppConfig'] = {productName: '26981ed0d57bbad37e728ff58134270c', deleteIsEnforced:  false , sealIsEnforced:  false , heartbeatRate:  0.5 , periodicReportingRateMillis:  60000.0 , disableAllReporting:  false };(function(){'use strict';function k(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}}function l(a){var b=typeof Symbol!="undefined"&&Symbol.iterator&&a[Symbol.iterator];if(b)return b.call(a);if(typeof a.length=="number")return{next:k(a)};throw Error(String(a)+" is not an iterable or ArrayLike");}var m=typeof Object.defineProperties=="function"?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a};
# ...
